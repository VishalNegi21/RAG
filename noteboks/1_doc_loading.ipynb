# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Text Doucment Loader

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader(file_path="../data/text_data.txt")

# %%
loader

# %%
texts = loader.load()

# %%
texts
# Out:
# [Document(metadata={'source': '../data/text_data.txt'}, page_content="Artificial Intelligence (AI)\n\nArtificial Intelligence is a branch of computer science that focuses on creating systems capable of performing tasks that normally require human intelligence. These tasks include learning, reasoning, problem-solving, language understanding, and decision-making.\n\nMachine Learning (ML)\n\nMachine Learning is a subset of AI where computers learn patterns from data instead of being explicitly programmed. ML algorithms improve their performance as they are exposed to more data. Common types of machine learning include supervised learning, unsupervised learning, and reinforcement learning.\n\nDeep Learning (DL)\n\nDeep Learning is a subset of machine learning that uses artificial neural networks with multiple layers. It is particularly effective for tasks such as image classification, speech recognition, and natural language processing.\n\nLarge Language Models (LLMs)\n\nLarge Language M
# ...

# %%
len(texts)
# Out:
# 1

# %% [markdown]
# ### PDF Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/a.pdf")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6256\3573730322.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
docs = loader.load()

# %%
print(len(docs))
# Out:
# 15

# %%
oneDoc = docs[0]
print(oneDoc.page_content)  # content of first page
# Out:
# Provided proper attribution is provided, Google hereby grants permission to
# reproduce the tables and figures in this paper solely for use in journalistic or
# scholarly works.
# Attention Is All You Need
# Ashish Vaswani∗
# Google Brain
# avaswani@google.com
# Noam Shazeer∗
# Google Brain
# noam@google.com
# Niki Parmar∗
# Google Research
# nikip@google.com
# Jakob Uszkoreit∗
# Google Research
# usz@google.com
# Llion Jones∗
# Google Research
# llion@google.com
# Aidan N. Gomez∗ †
# University of Toronto
# aidan@cs.toronto.edu
# Łukasz Kaiser∗
# Google Brain
# lukaszkaiser@google.com
# Illia Polosukhin∗ ‡
# illia.polosukhin@gmail.com
# Abstract
# The dominant sequence transduction models are based on complex recurrent or
# convolutional neural networks that include an encoder and a decoder. The best
# performing models also connect the encoder and decoder through an attention
# mechanism. We propose a new simple network architecture, the Transformer,
# ...

# %% [markdown]
# ### Web Page Loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path="https://codebasics.io/resources#featured")
docs = loader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
len(docs)
# Out:
# 1

# %%
docs[0].page_content
# Out:
# 'Data Analysis, AI & Data Science, Career Resources | CodebasicsAI PRO:Build real AI skills every weekStart Now →CoursesAdvanced CoursesMicro CoursesFree CoursesResourcesLearning MaterialsBlogsData ChallengesEventsAI & Data Fest 2025All EventsTestimonialsCourse ReviewJob Success StoriesHire TalentAI PROResourcesGet What You Need To LearnDownload practical resources that support your learning — frombeginner guides to real-world project templates.Data AnalysisAI & Data ScienceCareer AdviceInterview QuestionsLooking for Something Else?Explore All ResourcesGet Regular Updates!Join our WhatsApp Community to get notified about free resources. Join WhatsApp CommunityLearn from the most loved upskilling platform. With 80% of our resources free, we’re enabling careers, and yours could be next.Quick LinksCoursesBlogsData ChallengesHire TalentCodebasics FoundationHelp & SupportRefund PolicyTerms & ConditionsPrivacy PolicyCertificate VerificationBusiness InquiriesContact UsExplore CoursesAI & Da
# ...
